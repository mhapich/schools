# %% [markdown]
# # Research for Action: Pennsylvania School Data Project

# %% [markdown]
# After downloading data from [RFA](https://www.researchforaction.org/pa-school-data-project/), I loaded one of the files into Tableau, only to see a *very* large number of columns.  It will be easier for me to look at the data using `Pandas` and to save new, smaller files that I will use in Tableau.

# %% [markdown]
# My official citation of the data: (n.d.). *Pennsylvania School Data Project*. RFA. Retrieved December 12, 2023, from Research for Action. "Pennsylvania School Data Project."

# %% [markdown]
# ### Import packages

# %%
# pandas for dataframes, and the rest for some preliminary exploration of the data before using in Tableau

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Read in datasets

# %%
finance_state = pd.read_excel("./Datasets/finance_State_Jul_2018.xlsx")

# %%
opportunities_state = pd.read_excel("./Datasets/opportunities_State_Jul_2018.xlsx")

# %%
outcomes_state = pd.read_excel("./Datasets/outcomes_State_Jul_2018.xlsx")

# %%
# outcomes_school = pd.read_excel("./Datasets/outcomes_School_Jul_2018.xlsx")

# %% [markdown]
# ^^^ This file is MUCH larger than the rest and is taking a long time to load.  I'll check it out in google sheets later to see how it is different from outcomes_State...

# %%
people_state = pd.read_excel("./Datasets/people_State_Jul_2018.xlsx")

# %% [markdown]
# #### Check column name information - not consistent among all files

# %%
finance_state.head(3)
# Out:
#             year                         aun  \
# 0  Academic Year  Administrative Unit Number
# 1      2006-2007                   999999999
# 2      2007-2008                   999999999
#
#                                           nces_leaid  \
# 0  Agency ID - NCES Assigned [District] Latest av...
# 1                                                NaN
# 2                                                NaN
#
#                              leaname                            leatype  \
# 0  Local Education Agency (LEA) Name  Local Education Agency (LEA) Type
# 1              STATE OF PENNSYLVANIA                         State-wide
# 2              STATE OF PENNSYLVANIA                         State-wide
#
#      schoolnumber  nces_schid             schoolname   opendate    closedate  \
# 0  PA School Code  nces_schid            School Name  Open Date  Closed Date
# 1            9999         NaN  STATE OF PENNSYLVANIA        NaN          NaN
# 2            9999         NaN  STATE OF PENNSYLVANIA        NaN          NaN
#
#    ...                                 rev_9380  \
# 0  ...  Revenues Other: Activity Fund Transfers
# 1  ...                                 23341.97
# 2  ...                                  52672.2
#
#                                    rev_9390  \
# 0  Revenues Other: Permanent Fund Transfers
# 1                      Not Reported in Year
# 2                      Not Reported in Year
#
#                                             rev_9400  \
# 0  Revenues Other: Sale or Compensatio for Loss o...
# 1                                        13741926.21
# 2                                        13423110.77
#
#                                 rev_9500  \
# 0  Revenues Other: Capital Contributions
# 1                   Not Reported in Year
# 2                   Not Reported in Year
#
#                                          rev_9710  \
# 0  Revenues Other: Transfers from Component Units
# 1                                        520292.3
# 2                                           97814
#
#                                             rev_9720  \
# 0  Revenues Other: Transfers from Primary Governm...
# 1                                         1383136.07
# 2                                         1751722.71
#
#                                             rev_9910  \
# 0  Revenues Other: Other Financing Sources Not Li...
# 1                               Not Reported in Year
# 2                                         6025483.39
#
#                                 rev_9920  \
# 0  Revenues Other: Special Items - Gains
# 1                   Not Reported in Year
# 2                   Not Reported in Year
#
#                                       rev_9930  \
# 0  Revenues Other: Extraordinary Items - Gains
# 1                         Not Reported in Year
# 2                         Not Reported in Year
#
#                                rev_9990
# 0  Revenues Other: Insurance Recoveries
# 1                  Not Reported in Year
# 2                             1418128.5
#
# [3 rows x 431 columns]

# %%
opportunities_state.head(3)
# Out:
#   Academic Year Administrative Unit Number  \
# 0          year                        aun
# 1     2006-2007                  999999999
# 2     2007-2008                  999999999
#
#   Agency ID - NCES Assigned [District] Latest available year  \
# 0                                         nces_leaid
# 1                                                NaN
# 2                                                NaN
#
#   Local Education Agency (LEA) Name Local Education Agency (LEA) Type  \
# 0                           leaname                           leatype
# 1             STATE OF PENNSYLVANIA                        State-wide
# 2             STATE OF PENNSYLVANIA                        State-wide
#
#   PA School Code  nces_schid            School Name Opened Date Closed Date  \
# 0   schoolnumber  nces_schid             schoolname    opendate   closedate
# 1           9999         NaN  STATE OF PENNSYLVANIA         NaN         NaN
# 2           9999         NaN  STATE OF PENNSYLVANIA         NaN         NaN
#
#    ... CRDC: Number of Single-Sex Teams Offered. For Females.  \
# 0  ...                                       crdc_teams_f
# 1  ...                               Not Reported in Year
# 2  ...                               Not Reported in Year
#
#   CRDC: Number of Single-Sex Teams Offered. Total.  \
# 0                                 crdc_teams_total
# 1                             Not Reported in Year
# 2                             Not Reported in Year
#
#   CRDC: Number of Participants in Interscholastic Athletics. Male.  \
# 0                              crdc_athletics_part_m
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Number of Participants in Interscholastic Athletics. Female.  \
# 0                              crdc_athletics_part_f
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Number of Participants in Interscholastic Athletics. Total.  \
# 0                          crdc_athletics_part_total
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: FTE Teachers. Total. CRDC: FTE Teachers. Certified.  \
# 0        crdc_fteteach_total             crdc_fteteech_cert
# 1       Not Reported in Year           Not Reported in Year
# 2       Not Reported in Year           Not Reported in Year
#
#   CRDC: FTE Teachers in Their First Year  \
# 0                       crdc_fteteach_fy
# 1                   Not Reported in Year
# 2                   Not Reported in Year
#
#   CRDC: FTE Teachers in Their Second Year  \
# 0                        crdc_fteteach_sy
# 1                    Not Reported in Year
# 2                    Not Reported in Year
#
#   CRDC: FTE Teachers Who Are Chronically Absent (10 or More Days)
# 0                               crdc_fteteach_absent
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
# [3 rows x 171 columns]

# %%
outcomes_state.head(3)
# Out:
#   Academic Year Administrative Unit Number  \
# 0          year                        aun
# 1     2006-2007                  999999999
# 2     2007-2008                  999999999
#
#   Agency ID - NCES Assigned [District] Latest available year  \
# 0                                         nces_leaid
# 1                                                NaN
# 2                                                NaN
#
#   Local Education Agency (LEA) Name Local Education Agency (LEA) Type  \
# 0                           leaname                           leatype
# 1             STATE OF PENNSYLVANIA                        State-wide
# 2             STATE OF PENNSYLVANIA                        State-wide
#
#   PA School Code  nces_schid            School Name Open Date Closed Date  \
# 0   schoolnumber  nces_schid             schoolname  opendate   closedate
# 1           9999         NaN  STATE OF PENNSYLVANIA       NaN         NaN
# 2           9999         NaN  STATE OF PENNSYLVANIA       NaN         NaN
#
#    ... CRDC: Students Receiving An Expulsion. Female. Hispanic.  \
# 0  ...                                    crdc_exp_f_hisp
# 1  ...                               Not Reported in Year
# 2  ...                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. American Native.  \
# 0                                     crdc_exp_f_ame
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. Asian.  \
# 0                                   crdc_exp_f_asian
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. Pacific Islander.  \
# 0                                    crdc_exp_f_nhpi
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. Black.  \
# 0                                   crdc_exp_f_black
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. White.  \
# 0                                   crdc_exp_f_white
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. Two or More Races.  \
# 0                                      crdc_exp_f_tr
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. Total.  \
# 0                                   crdc_exp_f_total
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. LEP.  \
# 0                                     crdc_exp_f_lep
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   CRDC: Students Receiving An Expulsion. Female. IDEA.
# 0                                    crdc_exp_f_idea
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
# [3 rows x 818 columns]

# %%
people_state.head(3)
# Out:
#   Academic Year Administrative Unit Number  \
# 0          year                        aun
# 1     2006-2007                  999999999
# 2     2007-2008                  999999999
#
#   Agency ID - NCES Assigned [District] Latest available year  \
# 0                                         nces_leaid
# 1                                                NaN
# 2                                                NaN
#
#   Local Education Agency (LEA) Name Local Education Agency (LEA) Type  \
# 0                           leaname                           leatype
# 1             STATE OF PENNSYLVANIA                        State-wide
# 2             STATE OF PENNSYLVANIA                        State-wide
#
#   PA School Code  nces_schid            School Name Open Date Closed Date  \
# 0   schoolnumber  nces_schid             schoolname  opendate   closedate
# 1           9999         NaN  STATE OF PENNSYLVANIA       NaN         NaN
# 2           9999         NaN  STATE OF PENNSYLVANIA       NaN         NaN
#
#    ... Professional Staff: Classroom Teacher. Average Level of Education.  \
# 0  ...                                    prof_teach_educ
# 1  ...                               Not Reported in Year
# 2  ...                               Not Reported in Year
#
#   Professional Staff: Coordinate Services. Average Level of Education.  \
# 0                                    prof_coord_educ
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#   Professional Staff: Other. Average Level of Education.  \
# 0                                    prof_other_educ
# 1                               Not Reported in Year
# 2                               Not Reported in Year
#
#        Pupil/Teacher Ratio Number of Full-Time Equivalent (FTE) Teachers  \
# 0  ccd_pupil_teacher_ratio                              ccd_fte_teachers
# 1                     15.2                                        123114
# 2                     13.3                                        135234
#
#   Number of Prekindergarten Teachers Number of Elementary Teachers  \
# 0                  ccd_prek_teachers       ccd_elementary_teachers
# 1                                348                         45181
# 2                            Missing                       Missing
#
#   Number of Secondary Teachers Number of Ungraded Teachers  \
# 0       ccd_secondary_teachers       ccd_ungraded_teachers
# 1                        53274                       19755
# 2                      63317.6                     Missing
#
#   Number of Kindergarten Teachers
# 0             ccd_kinder_teachers
# 1                            4818
# 2                         Missing
#
# [3 rows x 301 columns]

# %% [markdown]
# We can see that the finance_state has the descriptive column names as row 1 of the dataframe, and has short names with no spaces as column names.<br>
# The other 3 dataframes we read in have the descriptive column names as actual column names, and the short names with no spaces are in row 1.<br><br>
# For ease of accessing infomation from each column, we will use the short names for column headings.  Before getting rid of the longer descriptions, I will create a text file that will be a dictionary with keys of short names and longer descriptions as values.

# %% [markdown]
# ## Write full, descriptive column names to text files

# %%
# define a function to create the text file of short column names with the longer descriptions

def create_cols_dict(short_cols, descriptions, filename):
    """
    Takes two lists and creates a dictionary of short names for keys and descriptions for values.
    Also takes filename to be created as a string
    Creates a text file where each line is in the format.... key : value
    This will be written back to the Datasets folder which needs to be in the current directory.
    The dictionary will be returned for possible further use.
    """
    
    # create empty dictionary
    column_dict = {}
    
    # fill dictionary with key-value pairs
    for short, long in zip(short_cols, descriptions):
        column_dict[short] = long
    
    # write short column names : longer descriptive column name to a text file
    filepath = './Datasets/' + filename
    f = open(filepath, "w")
    for key, value in column_dict.items():
        f.write(key + ' : ' + value + '\n')
    f.close()
    
    # return the dictionary
    return column_dict

# %%
descriptions = [col for col in people_state.columns]
len(descriptions)
# Out:
# 301

# %%
short_cols = people_state.iloc[0,:]
short_cols = short_cols.tolist()
len(short_cols)
# Out:
# 301

# %%
people_cols_dict = create_cols_dict(short_cols, descriptions, "people_state_columns.txt")

# %%
descriptions = [col for col in opportunities_state.columns]
len(descriptions)
# Out:
# 171

# %%
short_cols = opportunities_state.iloc[0,:]
short_cols = short_cols.tolist()
len(short_cols)
# Out:
# 171

# %%
opportunities_cols_dict = create_cols_dict(short_cols, descriptions, "opportunities_state_columns.txt")

# %%
descriptions = [col for col in outcomes_state.columns]
len(descriptions)
# Out:
# 818

# %%
short_cols = outcomes_state.iloc[0,:]
short_cols = short_cols.tolist()
len(short_cols)
# Out:
# 818

# %%
outcomes_cols_dict = create_cols_dict(short_cols, descriptions, "outcomes_state_columns.txt")

# %% [markdown]
# Be sure to do this one differently to get the two lists, since its header and first row were the opposite way of the other three.

# %%
short_cols = [col for col in finance_state.columns]
len(short_cols)
# Out:
# 431

# %%
descriptions = finance_state.iloc[0,:]
descriptions = descriptions.tolist()
len(descriptions)
# Out:
# 431

# %%
finance_cols_dict = create_cols_dict(short_cols, descriptions, "finance_state_columns.txt")

# %% [markdown]
# ## Create consistent dataframes where header is short column names, and first row is no longer the other column names

# %%
finance = finance_state.drop(index=0)
finance.head(2)
# Out:
#         year        aun nces_leaid                leaname     leatype  \
# 1  2006-2007  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
# 2  2007-2008  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
#
#   schoolnumber nces_schid             schoolname opendate closedate  ...  \
# 1         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
# 2         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
#
#    rev_9380              rev_9390     rev_9400              rev_9500  \
# 1  23341.97  Not Reported in Year  13741926.21  Not Reported in Year
# 2   52672.2  Not Reported in Year  13423110.77  Not Reported in Year
#
#    rev_9710    rev_9720              rev_9910              rev_9920  \
# 1  520292.3  1383136.07  Not Reported in Year  Not Reported in Year
# 2     97814  1751722.71            6025483.39  Not Reported in Year
#
#                rev_9930              rev_9990
# 1  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year             1418128.5
#
# [2 rows x 431 columns]

# %% [markdown]
# The other 3 will also need their column names changed.

# %%
len(finance.schoolname.value_counts())==1
# Out:
# True

# %%
opportunities = opportunities_state.drop(index=0)
opportunities.columns = list(opportunities_cols_dict.keys())
opportunities.head(2)
# Out:
#         year        aun nces_leaid                leaname     leatype  \
# 1  2006-2007  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
# 2  2007-2008  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
#
#   schoolnumber nces_schid             schoolname opendate closedate  ...  \
# 1         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
# 2         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
#
#            crdc_teams_f      crdc_teams_total crdc_athletics_part_m  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#   crdc_athletics_part_f crdc_athletics_part_total   crdc_fteteach_total  \
# 1  Not Reported in Year      Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year      Not Reported in Year  Not Reported in Year
#
#      crdc_fteteech_cert      crdc_fteteach_fy      crdc_fteteach_sy  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#    crdc_fteteach_absent
# 1  Not Reported in Year
# 2  Not Reported in Year
#
# [2 rows x 171 columns]

# %%
outcomes = outcomes_state.drop(index=0)
outcomes.columns = list(outcomes_cols_dict.keys())
outcomes.head(2)
# Out:
#         year        aun nces_leaid                leaname     leatype  \
# 1  2006-2007  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
# 2  2007-2008  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
#
#   schoolnumber nces_schid             schoolname opendate closedate  ...  \
# 1         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
# 2         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
#
#         crdc_exp_f_hisp        crdc_exp_f_ame      crdc_exp_f_asian  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#         crdc_exp_f_nhpi      crdc_exp_f_black      crdc_exp_f_white  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#           crdc_exp_f_tr      crdc_exp_f_total        crdc_exp_f_lep  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#         crdc_exp_f_idea
# 1  Not Reported in Year
# 2  Not Reported in Year
#
# [2 rows x 818 columns]

# %%
people = people_state.drop(index=0)
people.columns = list(people_cols_dict.keys())
people.head(2)
# Out:
#         year        aun nces_leaid                leaname     leatype  \
# 1  2006-2007  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
# 2  2007-2008  999999999        NaN  STATE OF PENNSYLVANIA  State-wide
#
#   schoolnumber nces_schid             schoolname opendate closedate  ...  \
# 1         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
# 2         9999        NaN  STATE OF PENNSYLVANIA      NaN       NaN  ...
#
#         prof_teach_educ       prof_coord_educ       prof_other_educ  \
# 1  Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2  Not Reported in Year  Not Reported in Year  Not Reported in Year
#
#   ccd_pupil_teacher_ratio ccd_fte_teachers ccd_prek_teachers  \
# 1                    15.2           123114               348
# 2                    13.3           135234           Missing
#
#   ccd_elementary_teachers ccd_secondary_teachers ccd_ungraded_teachers  \
# 1                   45181                  53274                 19755
# 2                 Missing                63317.6               Missing
#
#   ccd_kinder_teachers
# 1                4818
# 2             Missing
#
# [2 rows x 301 columns]

# %% [markdown]
# ## Choosing Columns to Keep

# %% [markdown]
# ### In finance

# %%
people.aun.unique()[0]
# Out:
# '999999999'

# %% [markdown]
# There are many columns that have the same value for every row (every year). Those will be columns to be dropped.<br>
# Look at the unique single value in the column just to be sure.

# %%
cols_one_value = []
for col in finance.columns:
    if len(finance[col].value_counts())<=1:
        print(f'{col} : {finance[col].unique()[0]}')
        cols_one_value.append(col)
# Out:
# aun : 999999999
# nces_leaid : nan
# leaname : STATE OF PENNSYLVANIA
# leatype : State-wide
# schoolnumber : 9999
# nces_schid : nan
# schoolname : STATE OF PENNSYLVANIA
# opendate : nan
# closedate : nan
# schooltype : nan
# county : nan
# gradeserved_pk : Yes
# gradeserved_pka : Yes
# gradeserved_pkp : Yes
# gradeserved_pkf : Yes
# gradeserved_k : Yes
# gradeserved_k4a : Yes
# gradeserved_k4p : Yes
# gradeserved_k4f : Yes
# gradeserved_k5a : Yes
# gradeserved_k5p : Yes
# gradeserved_k5f : Yes
# gradeserved_1st : Yes
# gradeserved_2nd : Yes
# gradeserved_3rd : Yes
# gradeserved_4th : Yes
# gradeserved_5th : Yes
# gradeserved_6th : Yes
# gradeserved_7th : Yes
# gradeserved_8th : Yes
# gradeserved_9th : Yes
# gradeserved_10th : Yes
# gradeserved_11th : Yes
# gradeserved_12th : Yes
# gradeserved_ug : Yes
# adm : nan
# wadm : nan
# exp_adm_1000 : nan
# exp_adm_2000 : nan
# exp_adm_3000 : nan
# exp_adm_current : nan
# exp_adm_4000 : nan
# exp_adm_5000 : nan
# exp_adm_total : nan
# exp_wadm_aie : nan
# rev_adm_total : nan
# rev_adm_local : nan
# rev_adm_state : nan
# rev_adm_federal : nan
# rev_adm_other : nan

# %%
finance.drop(cols_one_value, axis=1, inplace=True)
finance.shape
# Out:
# (11, 381)

# %%
finance.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 1 to 11
# Data columns (total 381 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    year                              11 non-null     object
#  1    exp_1000                          11 non-null     object
#  2    exp_2000                          11 non-null     object
#  3    exp_3000                          11 non-null     object
#  4    exp_current                       11 non-null     object
#  5    exp_4000                          11 non-null     object
#  6    exp_5000                          11 non-null     object
#  7    exp_total                         11 non-null     object
#  8    exp_aie                           11 non-null     object
#  9    exp_1100                          11 non-null     object
#  10   exp_1200                          11 non-null     object
#  11   exp_1300                          11 non-null     object
#  12   exp_1400                          11 non-null     object
#  13   exp_1500                          11 non-null     object
#  14   exp_1600                          11 non-null     object
#  15   exp_1700                          11 non-null     object
#  16   exp_1800                          11 non-null     object
#  17   exp_2100                          11 non-null     object
#  18   exp_2200                          11 non-null     object
#  19   exp_2300                          11 non-null     object
#  20   exp_2400                          11 non-null     object
#  21   exp_2500                          11 non-null     object
#  22   exp_2600                          11 non-null     object
#  23   exp_2700                          11 non-null     object
#  24   exp_2800                          11 non-null     object
#  25   exp_2900                          11 non-null     object
#  26   exp_1140                          11 non-null     object
#  27   exp_1190                          11 non-null     object
#  28   exp_1210                          11 non-null     object
#  29   exp_1220                          11 non-null     object
#  30   exp_1230                          11 non-null     object
#  31   exp_1241                          11 non-null     object
#  32   exp_1242                          11 non-null     object
#  33   exp_1243                          11 non-null     object
#  34   exp_1260                          11 non-null     object
#  35   exp_1270                          11 non-null     object
#  36   exp_1280                          11 non-null     object
#  37   exp_1290                          11 non-null     object
#  38   exp_1410                          11 non-null     object
#  39   exp_1420                          11 non-null     object
#  40   exp_1430                          11 non-null     object
#  41   exp_1440                          11 non-null     object
#  42   exp_1441                          11 non-null     object
#  43   exp_1442                          11 non-null     object
#  44   exp_1450                          11 non-null     object
#  45   exp_1490                          11 non-null     object
#  46   exp_1801                          11 non-null     object
#  47   exp_1802                          11 non-null     object
#  48   exp_1803                          11 non-null     object
#  49   exp_1804                          11 non-null     object
#  50   exp_1805                          11 non-null     object
#  51   exp_1806                          11 non-null     object
#  52   exp_1807                          11 non-null     object
#  53   exp_2110                          11 non-null     object
#  54   exp_2111                          11 non-null     object
#  55   exp_2119                          11 non-null     object
#  56   exp_2120                          11 non-null     object
#  57   exp_2130                          11 non-null     object
#  58   exp_2140                          11 non-null     object
#  59   exp_2150                          11 non-null     object
#  60   exp_2160                          11 non-null     object
#  61   exp_2170                          11 non-null     object
#  62   exp_2190                          11 non-null     object
#  63   exp_2211                          11 non-null     object
#  64   exp_2219                          11 non-null     object
#  65   exp_2220                          11 non-null     object
#  66   exp_2230                          11 non-null     object
#  67   exp_2240                          11 non-null     object
#  68   exp_2250                          11 non-null     object
#  69   exp_2260                          11 non-null     object
#  70   exp_2270                          11 non-null     object
#  71   exp_2280                          11 non-null     object
#  72   exp_2290                          11 non-null     object
#  73   exp_2310                          11 non-null     object
#  74   exp_2320                          11 non-null     object
#  75   exp_2330                          11 non-null     object
#  76   exp_2340                          11 non-null     object
#  77   exp_2350                          11 non-null     object
#  78   exp_2360                          11 non-null     object
#  79   exp_2370                          11 non-null     object
#  80   exp_2380                          11 non-null     object
#  81   exp_2390                          11 non-null     object
#  82   exp_2411                          11 non-null     object
#  83   exp_2419                          11 non-null     object
#  84   exp_2420                          11 non-null     object
#  85   exp_2430                          11 non-null     object
#  86   exp_2440                          11 non-null     object
#  87   exp_2450                          11 non-null     object
#  88   exp_2490                          11 non-null     object
#  89   exp_2511                          11 non-null     object
#  90   exp_2512                          11 non-null     object
#  91   exp_2513                          11 non-null     object
#  92   exp_2514                          11 non-null     object
#  93   exp_2515                          11 non-null     object
#  94   exp_2516                          11 non-null     object
#  95   exp_2517                          11 non-null     object
#  96   exp_2519                          11 non-null     object
#  97   exp_2520                          11 non-null     object
#  98   exp_2530                          11 non-null     object
#  99   exp_2540                          11 non-null     object
#  100  exp_2590                          11 non-null     object
#  101  exp_2611                          11 non-null     object
#  102  exp_2619                          11 non-null     object
#  103  exp_2620                          11 non-null     object
#  104  exp_2630                          11 non-null     object
#  105  exp_2640                          11 non-null     object
#  106  exp_2650                          11 non-null     object
#  107  exp_2660                          11 non-null     object
#  108  exp_2690                          11 non-null     object
#  109  exp_2711                          11 non-null     object
#  110  exp_2719                          11 non-null     object
#  111  exp_2720                          11 non-null     object
#  112  exp_2730                          11 non-null     object
#  113  exp_2740                          11 non-null     object
#  114  exp_2750                          11 non-null     object
#  115  exp_2790                          11 non-null     object
#  116  exp_2810                          11 non-null     object
#  117  exp_2821                          11 non-null     object
#  118  exp_2822                          11 non-null     object
#  119  exp_2823                          11 non-null     object
#  120  exp_2824                          11 non-null     object
#  121  exp_2829                          11 non-null     object
#  122  exp_2831                          11 non-null     object
#  123  exp_2832                          11 non-null     object
#  124  exp_2833                          11 non-null     object
#  125  exp_2834                          11 non-null     object
#  126  exp_2835                          11 non-null     object
#  127  exp_2836                          11 non-null     object
#  128  exp_2839                          11 non-null     object
#  129  exp_2840                          11 non-null     object
#  130  exp_2850                          11 non-null     object
#  131  exp_2860                          11 non-null     object
#  132  exp_2890                          11 non-null     object
#  133  exp_2910                          11 non-null     object
#  134  exp_2990                          11 non-null     object
#  135  exp_3100                          11 non-null     object
#  136  exp_3200                          11 non-null     object
#  137  exp_3300                          11 non-null     object
#  138  exp_3400                          11 non-null     object
#  139  exp_4100                          11 non-null     object
#  140  exp_4200                          11 non-null     object
#  141  exp_4300                          11 non-null     object
#  142  exp_4400                          11 non-null     object
#  143  exp_4500                          11 non-null     object
#  144  exp_4600                          11 non-null     object
#  145  exp_5100                          11 non-null     object
#  146  exp_5110                          11 non-null     object
#  147  exp_5120                          11 non-null     object
#  148  exp_5130                          11 non-null     object
#  149  exp_5140                          11 non-null     object
#  150  exp_5150                          11 non-null     object
#  151  exp_5200                          11 non-null     object
#  152  exp_5220                          11 non-null     object
#  153  exp_5230                          11 non-null     object
#  154  exp_5240                          11 non-null     object
#  155  exp_5250                          11 non-null     object
#  156  exp_5260                          11 non-null     object
#  157  exp_5270                          11 non-null     object
#  158  exp_5280                          11 non-null     object
#  159  exp_5290                          11 non-null     object
#  160  exp_5300                          11 non-null     object
#  161  exp_5310                          11 non-null     object
#  162  exp_5320                          11 non-null     object
#  163  exp_5520                          11 non-null     object
#  164  exp_5530                          11 non-null     object
#  165  exp_100                           11 non-null     object
#  166  exp_200                           11 non-null     object
#  167  exp_220                           11 non-null     object
#  168  exp_230                           11 non-null     object
#  169  exp_300                           11 non-null     object
#  170  exp_400                           11 non-null     object
#  171  exp_500                           11 non-null     object
#  172  exp_600                           11 non-null     object
#  173  exp_700                           11 non-null     object
#  174  exp_800                           11 non-null     object
#  175  exp_900                           11 non-null     object
#  176  exp_tuition_othsd                 11 non-null     object
#  177  exp_tuition_charter_brck_nonspec  11 non-null     object
#  178  exp_tuition_charter_cyb_nonspec   11 non-null     object
#  179  exp_tuition_charter_brck_spec     11 non-null     object
#  180  exp_tuition_charter_cyb_spec      11 non-null     object
#  181  exp_tuition_nonpublic             11 non-null     object
#  182  exp_tuition_ctc                   11 non-null     object
#  183  exp_tuition_highered              11 non-null     object
#  184  exp_tuition_private               11 non-null     object
#  185  exp_tuition_prris                 11 non-null     object
#  186  exp_tuition_othlea                11 non-null     object
#  187  exp_tuition_charter_nonspec       11 non-null     object
#  188  exp_tuition_charter_spec          11 non-null     object
#  189  exp_tuition_charter               11 non-null     object
#  190  exp_tuition_unassigned            11 non-null     object
#  191  rev_total                         11 non-null     object
#  192  rev_local_tax                     11 non-null     object
#  193  rev_local_other                   11 non-null     object
#  194  rev_6000                          11 non-null     object
#  195  rev_local_pct                     11 non-null     object
#  196  rev_7000                          11 non-null     object
#  197  rev_state_pct                     11 non-null     object
#  198  rev_8000                          11 non-null     object
#  199  rev_federal_pct                   11 non-null     object
#  200  rev_9000                          11 non-null     object
#  201  rev_other_pct                     11 non-null     object
#  202  rev_tax_total                     11 non-null     object
#  203  rev_tax_realestate                11 non-null     object
#  204  rev_tax_realty                    11 non-null     object
#  205  rev_tax_lieu                      11 non-null     object
#  206  rev_tax_percapita                 11 non-null     object
#  207  rev_tax_1stclass                  11 non-null     object
#  208  rev_tax_delinquent                11 non-null     object
#  209  rev_tax_steb                      11 non-null     object
#  210  rev_eq_mills                      11 non-null     object
#  211  rev_6111                          11 non-null     object
#  212  rev_6112                          11 non-null     object
#  213  rev_6113                          11 non-null     object
#  214  rev_6114                          11 non-null     object
#  215  rev_6115                          11 non-null     object
#  216  rev_6120                          11 non-null     object
#  217  rev_6131                          11 non-null     object
#  218  rev_6141                          11 non-null     object
#  219  rev_6142                          11 non-null     object
#  220  rev_6143                          11 non-null     object
#  221  rev_6144                          11 non-null     object
#  222  rev_6145                          11 non-null     object
#  223  rev_6146                          11 non-null     object
#  224  rev_6149                          11 non-null     object
#  225  rev_6151                          11 non-null     object
#  226  rev_6152                          11 non-null     object
#  227  rev_6153                          11 non-null     object
#  228  rev_6154                          11 non-null     object
#  229  rev_6155                          11 non-null     object
#  230  rev_6156                          11 non-null     object
#  231  rev_6157                          11 non-null     object
#  232  rev_6159                          11 non-null     object
#  233  rev_6161                          11 non-null     object
#  234  rev_6162                          11 non-null     object
#  235  rev_6163                          11 non-null     object
#  236  rev_6164                          11 non-null     object
#  237  rev_6165                          11 non-null     object
#  238  rev_6166                          11 non-null     object
#  239  rev_6167                          11 non-null     object
#  240  rev_6168                          11 non-null     object
#  241  rev_6169                          11 non-null     object
#  242  rev_6400                          11 non-null     object
#  243  rev_6500                          11 non-null     object
#  244  rev_6600                          11 non-null     object
#  245  rev_6700                          11 non-null     object
#  246  rev_6810                          11 non-null     object
#  247  rev_6821                          11 non-null     object
#  248  rev_6829                          11 non-null     object
#  249  rev_6831                          11 non-null     object
#  250  rev_6832                          11 non-null     object
#  251  rev_6833                          11 non-null     object
#  252  rev_6834                          11 non-null     object
#  253  rev_6835                          11 non-null     object
#  254  rev_6836                          11 non-null     object
#  255  rev_6839                          11 non-null     object
#  256  rev_6890                          11 non-null     object
#  257  rev_6910                          11 non-null     object
#  258  rev_6920                          11 non-null     object
#  259  rev_6941                          11 non-null     object
#  260  rev_6942                          11 non-null     object
#  261  rev_6943                          11 non-null     object
#  262  rev_6944                          11 non-null     object
#  263  rev_6945                          11 non-null     object
#  264  rev_6946                          11 non-null     object
#  265  rev_6949                          11 non-null     object
#  266  rev_6961                          11 non-null     object
#  267  rev_6962                          11 non-null     object
#  268  rev_6969                          11 non-null     object
#  269  rev_6970                          11 non-null     object
#  270  rev_6980                          11 non-null     object
#  271  rev_6991                          11 non-null     object
#  272  rev_6992                          11 non-null     object
#  273  rev_6999                          11 non-null     object
#  274  rev_7110                          11 non-null     object
#  275  rev_7140                          11 non-null     object
#  276  rev_7160                          11 non-null     object
#  277  rev_7170                          11 non-null     object
#  278  rev_7180                          11 non-null     object
#  279  rev_7210                          11 non-null     object
#  280  rev_7220                          11 non-null     object
#  281  rev_7230                          11 non-null     object
#  282  rev_7240                          11 non-null     object
#  283  rev_7250                          11 non-null     object
#  284  rev_7260                          11 non-null     object
#  285  rev_7271                          11 non-null     object
#  286  rev_7272                          11 non-null     object
#  287  rev_7280                          11 non-null     object
#  288  rev_7291                          11 non-null     object
#  289  rev_7292                          11 non-null     object
#  290  rev_7299                          11 non-null     object
#  291  rev_7310                          11 non-null     object
#  292  rev_7311                          11 non-null     object
#  293  rev_7312                          11 non-null     object
#  294  rev_7320                          11 non-null     object
#  295  rev_7330                          11 non-null     object
#  296  rev_7340                          11 non-null     object
#  297  rev_7350                          11 non-null     object
#  298  rev_7360                          11 non-null     object
#  299  rev_7400                          11 non-null     object
#  300  rev_7501                          11 non-null     object
#  301  rev_7502                          11 non-null     object
#  302  rev_7503                          11 non-null     object
#  303  rev_7505                          11 non-null     object
#  304  rev_7509                          11 non-null     object
#  305  rev_7510                          11 non-null     object
#  306  rev_7598                          11 non-null     object
#  307  rev_7599                          11 non-null     object
#  308  rev_7600                          11 non-null     object
#  309  rev_7810                          11 non-null     object
#  310  rev_7820                          11 non-null     object
#  311  rev_7910                          11 non-null     object
#  312  rev_7920                          11 non-null     object
#  313  rev_7990                          11 non-null     object
#  314  rev_8110                          11 non-null     object
#  315  rev_8190                          11 non-null     object
#  316  rev_8200                          11 non-null     object
#  317  rev_8310                          11 non-null     object
#  318  rev_8320                          11 non-null     object
#  319  rev_8390                          11 non-null     object
#  320  rev_8511                          11 non-null     object
#  321  rev_8512                          11 non-null     object
#  322  rev_8513                          11 non-null     object
#  323  rev_8514                          11 non-null     object
#  324  rev_8515                          11 non-null     object
#  325  rev_8516                          11 non-null     object
#  326  rev_8517                          11 non-null     object
#  327  rev_8518                          11 non-null     object
#  328  rev_8519                          11 non-null     object
#  329  rev_8521                          11 non-null     object
#  330  rev_8522                          11 non-null     object
#  331  rev_8530                          11 non-null     object
#  332  rev_8540                          11 non-null     object
#  333  rev_8560                          11 non-null     object
#  334  rev_8580                          11 non-null     object
#  335  rev_8610                          11 non-null     object
#  336  rev_8620                          11 non-null     object
#  337  rev_8640                          11 non-null     object
#  338  rev_8660                          11 non-null     object
#  339  rev_8670                          11 non-null     object
#  340  rev_8690                          11 non-null     object
#  341  rev_8701                          11 non-null     object
#  342  rev_8702                          11 non-null     object
#  343  rev_8703                          11 non-null     object
#  344  rev_8704                          11 non-null     object
#  345  rev_8705                          11 non-null     object
#  346  rev_8706                          11 non-null     object
#  347  rev_8707                          11 non-null     object
#  348  rev_8708                          11 non-null     object
#  349  rev_8709                          11 non-null     object
#  350  rev_8721                          11 non-null     object
#  351  rev_8731                          11 non-null     object
#  352  rev_8732                          11 non-null     object
#  353  rev_8733                          11 non-null     object
#  354  rev_8735                          11 non-null     object
#  355  rev_8799                          11 non-null     object
#  356  rev_8810                          11 non-null     object
#  357  rev_8820                          11 non-null     object
#  358  rev_8830                          11 non-null     object
#  359  rev_9110                          11 non-null     object
#  360  rev_9120                          11 non-null     object
#  361  rev_9130                          11 non-null     object
#  362  rev_9200                          11 non-null     object
#  363  rev_9210                          11 non-null     object
#  364  rev_9290                          11 non-null     object
#  365  rev_9320                          11 non-null     object
#  366  rev_9330                          11 non-null     object
#  367  rev_9340                          11 non-null     object
#  368  rev_9350                          11 non-null     object
#  369  rev_9360                          11 non-null     object
#  370  rev_9370                          11 non-null     object
#  371  rev_9380                          11 non-null     object
#  372  rev_9390                          11 non-null     object
#  373  rev_9400                          11 non-null     object
#  374  rev_9500                          11 non-null     object
#  375  rev_9710                          11 non-null     object
#  376  rev_9720                          11 non-null     object
#  377  rev_9910                          11 non-null     object
#  378  rev_9920                          11 non-null     object
#  379  rev_9930                          11 non-null     object
#  380  rev_9990                          11 non-null     object
# dtypes: object(381)
# memory usage: 32.9+ KB

# %% [markdown]
# All columns contain 11 non-null object values.  Now convert all columns with all numbers to numeric types.

# %% [markdown]
# ### In opportunities

# %% [markdown]
# ### In outcomes

# %% [markdown]
# After examining all columns from all files (in the text files/dictionaries created above), I will first look at Keystone Exam percentages each year.  They will be broken down by
# - Advanced
# - Proficient
# - Basic
# - Below Basic <br>
# and also by
# - all students
# - HU students

# %% [markdown]
# According to [A Guide to Understanding School Performance Profiles](https://www.lmsd.org/uploaded/documents/Curriculum/SPPGuide.pdf), HU students are **historically underperforming**.<br>
# These students include:
# - students with IEPs
# - English learners
# - Economically disadvangaged students

# %% [markdown]
# Here are the columns descriptions along with the short names.

# %% [markdown]
# ks_number_alg_all : Keystone Exam: Number Tested, Algebra. All Students.<br>
# ks_number_alg_hus : Keystone Exam: Number Tested, Algebra. HU Students.<br>
# ks_number_bio_all : Keystone Exam: Number Tested, Biology. All Students.<br>
# ks_number_bio_hus : Keystone Exam: Number Tested, Biology. HU Students.<br>
# ks_number_lit_all : Keystone Exam: Number Tested, Literature . All Students.<br>
# ks_number_lit_hus : Keystone Exam: Number Tested, Literature . HU Students.<br>
# ks_adv_alg_all : Keystone Exam: Percent Advanced, Algebra. All Students.<br>
# ks_prof_alg_all : Keystone Exam: Percent Proficient, Algebra. All Students.<br>
# ks_basic_alg_all : Keystone Exam: Percent Basic, Algebra. All Students.<br>
# ks_below_alg_all : Keystone Exam: Percent Below Basic, Algebra. All Students.<br>
# ks_adv_alg_hus : Keystone Exam: Percent Advanced, Algebra. HU Students.<br>
# ks_prof_alg_hus : Keystone Exam: Percent Proficient, Algebra. HU Students.<br>
# ks_basic_alg_hus : Keystone Exam: Percent Basic, Algebra. HU Students.<br>
# ks_below_alg_hus : Keystone Exam: Percent Below Basic, Algebra. HU Students.<br>
# ks_adv_bio_all : Keystone Exam: Percent Advanced, Biology. All Students.<br>
# ks_prof_bio_all : Keystone Exam: Percent Proficient, Biology. All Students.<br>
# ks_basic_bio_all : Keystone Exam: Percent Basic, Biology. All Students.<br>
# ks_below_bio_all : Keystone Exam: Percent Below Basic, Biology. All Students.<br>
# ks_adv_bio_hus : Keystone Exam: Percent Advanced, Biology. HU Students.<br>
# ks_prof_bio_hus : Keystone Exam: Percent Proficient, Biology. HU Students.<br>
# ks_basic_bio_hus : Keystone Exam: Percent Basic, Biology. HU Students.<br>
# ks_below_bio_hus : Keystone Exam: Percent Below Basic, Biology. HU Students.<br>
# ks_adv_lit_all : Keystone Exam: Percent Advanced, Literature. All Students.<br>
# ks_prof_lit_all : Keystone Exam: Percent Proficient, Literature. All Students.<br>
# ks_basic_lit_all : Keystone Exam: Percent Basic, Literature. All Students.<br>
# ks_below_lit_all : Keystone Exam: Percent Below Basic, Literature. All Students.<br>
# ks_adv_lit_hus : Keystone Exam: Percent Advanced, Literature. HU Students.<br>
# ks_prof_lit_hus : Keystone Exam: Percent Proficient, Literature. HU Students.<br>
# ks_basic_lit_hus : Keystone Exam: Percent Basic, Literature. HU Students.<br>
# ks_below_lit_hus : Keystone Exam: Percent Below Basic, Literature. HU Students.<br>

# %%
outcomes.T
# Out:
#                                      1                      2   \
# year                          2006-2007              2007-2008
# aun                           999999999              999999999
# nces_leaid                          NaN                    NaN
# leaname           STATE OF PENNSYLVANIA  STATE OF PENNSYLVANIA
# leatype                      State-wide             State-wide
# ...                                 ...                    ...
# crdc_exp_f_white   Not Reported in Year   Not Reported in Year
# crdc_exp_f_tr      Not Reported in Year   Not Reported in Year
# crdc_exp_f_total   Not Reported in Year   Not Reported in Year
# crdc_exp_f_lep     Not Reported in Year   Not Reported in Year
# crdc_exp_f_idea    Not Reported in Year   Not Reported in Year
#
#                                      3                      4   \
# year                          2008-2009              2009-2010
# aun                           999999999              999999999
# nces_leaid                          NaN                    NaN
# leaname           STATE OF PENNSYLVANIA  STATE OF PENNSYLVANIA
# leatype                      State-wide             State-wide
# ...                                 ...                    ...
# crdc_exp_f_white   Not Reported in Year   Not Reported in Year
# crdc_exp_f_tr      Not Reported in Year   Not Reported in Year
# crdc_exp_f_total   Not Reported in Year   Not Reported in Year
# crdc_exp_f_lep     Not Reported in Year   Not Reported in Year
# crdc_exp_f_idea    Not Reported in Year   Not Reported in Year
#
#                                      5                      6   \
# year                          2010-2011              2011-2012
# aun                           999999999              999999999
# nces_leaid                          NaN                    NaN
# leaname           STATE OF PENNSYLVANIA  STATE OF PENNSYLVANIA
# leatype                      State-wide             State-wide
# ...                                 ...                    ...
# crdc_exp_f_white   Not Reported in Year                    742
# crdc_exp_f_tr      Not Reported in Year                     36
# crdc_exp_f_total   Not Reported in Year                   1873
# crdc_exp_f_lep     Not Reported in Year                     50
# crdc_exp_f_idea    Not Reported in Year                    209
#
#                                      7                      8   \
# year                          2012-2013              2013-2014
# aun                           999999999              999999999
# nces_leaid                          NaN                    NaN
# leaname           STATE OF PENNSYLVANIA  STATE OF PENNSYLVANIA
# leatype                      State-wide             State-wide
# ...                                 ...                    ...
# crdc_exp_f_white   Not Reported in Year                    383
# crdc_exp_f_tr      Not Reported in Year                     50
# crdc_exp_f_total   Not Reported in Year                    806
# crdc_exp_f_lep     Not Reported in Year                     16
# crdc_exp_f_idea    Not Reported in Year                    154
#
#                                      9                      10  \
# year                          2014-2015              2015-2016
# aun                           999999999              999999999
# nces_leaid                          NaN                    NaN
# leaname           STATE OF PENNSYLVANIA  STATE OF PENNSYLVANIA
# leatype                      State-wide             State-wide
# ...                                 ...                    ...
# crdc_exp_f_white   Not Reported in Year                    440
# crdc_exp_f_tr      Not Reported in Year                     54
# crdc_exp_f_total   Not Reported in Year                   1060
# crdc_exp_f_lep     Not Reported in Year                     34
# crdc_exp_f_idea    Not Reported in Year                    222
#
#                                      11
# year                          2016-2017
# aun                           999999999
# nces_leaid                          NaN
# leaname           STATE OF PENNSYLVANIA
# leatype                      State-wide
# ...                                 ...
# crdc_exp_f_white   Not Reported in Year
# crdc_exp_f_tr      Not Reported in Year
# crdc_exp_f_total   Not Reported in Year
# crdc_exp_f_lep     Not Reported in Year
# crdc_exp_f_idea    Not Reported in Year
#
# [818 rows x 11 columns]

# %% [markdown]
# #### Subset just columns with Keystone Information

# %%
keystone_indices = []
for index, (key, val) in enumerate(outcomes_cols_dict.items()):
    if 'ks_' in key:
        print(f'index: {index}, column name: {key}, \n  meaning: {val}')
        keystone_indices.append(index)
# Out:
# index: 444, column name: ks_number_alg_all,
#   meaning: Keystone Exam: Number Tested, Algebra. All Students.
# index: 445, column name: ks_number_alg_hus,
#   meaning: Keystone Exam: Number Tested, Algebra. HU Students.
# index: 446, column name: ks_number_bio_all,
#   meaning: Keystone Exam: Number Tested, Biology. All Students.
# index: 447, column name: ks_number_bio_hus,
#   meaning: Keystone Exam: Number Tested, Biology. HU Students.
# index: 448, column name: ks_number_lit_all,
#   meaning: Keystone Exam: Number Tested, Literature . All Students.
# index: 449, column name: ks_number_lit_hus,
#   meaning: Keystone Exam: Number Tested, Literature . HU Students.
# index: 450, column name: ks_adv_alg_all,
#   meaning: Keystone Exam: Percent Advanced, Algebra. All Students.
# index: 451, column name: ks_prof_alg_all,
#   meaning: Keystone Exam: Percent Proficient, Algebra. All Students.
# index: 452, column name: ks_basic_alg_all,
#   meaning: Keystone Exam: Percent Basic, Algebra. All Students.
# index: 453, column name: ks_below_alg_all,
#   meaning: Keystone Exam: Percent Below Basic, Algebra. All Students.
# index: 454, column name: ks_adv_alg_hus,
#   meaning: Keystone Exam: Percent Advanced, Algebra. HU Students.
# index: 455, column name: ks_prof_alg_hus,
#   meaning: Keystone Exam: Percent Proficient, Algebra. HU Students.
# index: 456, column name: ks_basic_alg_hus,
#   meaning: Keystone Exam: Percent Basic, Algebra. HU Students.
# index: 457, column name: ks_below_alg_hus,
#   meaning: Keystone Exam: Percent Below Basic, Algebra. HU Students.
# index: 458, column name: ks_adv_bio_all,
#   meaning: Keystone Exam: Percent Advanced, Biology. All Students.
# index: 459, column name: ks_prof_bio_all,
#   meaning: Keystone Exam: Percent Proficient, Biology. All Students.
# index: 460, column name: ks_basic_bio_all,
#   meaning: Keystone Exam: Percent Basic, Biology. All Students.
# index: 461, column name: ks_below_bio_all,
#   meaning: Keystone Exam: Percent Below Basic, Biology. All Students.
# index: 462, column name: ks_adv_bio_hus,
#   meaning: Keystone Exam: Percent Advanced, Biology. HU Students.
# index: 463, column name: ks_prof_bio_hus,
#   meaning: Keystone Exam: Percent Proficient, Biology. HU Students.
# index: 464, column name: ks_basic_bio_hus,
#   meaning: Keystone Exam: Percent Basic, Biology. HU Students.
# index: 465, column name: ks_below_bio_hus,
#   meaning: Keystone Exam: Percent Below Basic, Biology. HU Students.
# index: 466, column name: ks_adv_lit_all,
#   meaning: Keystone Exam: Percent Advanced, Literature. All Students.
# index: 467, column name: ks_prof_lit_all,
#   meaning: Keystone Exam: Percent Proficient, Literature. All Students.
# index: 468, column name: ks_basic_lit_all,
#   meaning: Keystone Exam: Percent Basic, Literature. All Students.
# index: 469, column name: ks_below_lit_all,
#   meaning: Keystone Exam: Percent Below Basic, Literature. All Students.
# index: 470, column name: ks_adv_lit_hus,
#   meaning: Keystone Exam: Percent Advanced, Literature. HU Students.
# index: 471, column name: ks_prof_lit_hus,
#   meaning: Keystone Exam: Percent Proficient, Literature. HU Students.
# index: 472, column name: ks_basic_lit_hus,
#   meaning: Keystone Exam: Percent Basic, Literature. HU Students.
# index: 473, column name: ks_below_lit_hus,
#   meaning: Keystone Exam: Percent Below Basic, Literature. HU Students.

# %%
# keystone_indices[-1]
# use numpy's .r_ to concatenate the slices of columns we need
outcomes_keystone = outcomes.iloc[:,np.r_[0,keystone_indices[0]:keystone_indices[-1]+1]]
outcomes_keystone
# Out:
#          year     ks_number_alg_all     ks_number_alg_hus  \
# 1   2006-2007  Not Reported in Year  Not Reported in Year
# 2   2007-2008  Not Reported in Year  Not Reported in Year
# 3   2008-2009  Not Reported in Year  Not Reported in Year
# 4   2009-2010  Not Reported in Year  Not Reported in Year
# 5   2010-2011  Not Reported in Year  Not Reported in Year
# 6   2011-2012  Not Reported in Year  Not Reported in Year
# 7   2012-2013                124220                 51202
# 8   2013-2014                123175                 53189
# 9   2014-2015                123091                 54760
# 10  2015-2016                123525                 56045
# 11  2016-2017                123648                 57299
#
#        ks_number_bio_all     ks_number_bio_hus     ks_number_lit_all  \
# 1   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 7                 122990                 50367                123966
# 8                 121505                 52052                122784
# 9                 122035                 53907                122568
# 10                122602                 55240                123292
# 11                122518                 56357                122697
#
#        ks_number_lit_hus        ks_adv_alg_all       ks_prof_alg_all  \
# 1   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 7                  50978                    27                  37.4
# 8                  52845                  16.9                  47.1
# 9                  54180                  17.7                  46.8
# 10                 55740                  20.6                  47.6
# 11                 56383                  22.2                  43.4
#
#         ks_basic_alg_all  ...      ks_basic_bio_hus      ks_below_bio_hus  \
# 1   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  ...  Not Reported in Year  Not Reported in Year
# 7                   26.1  ...                  32.5                  43.4
# 8                   26.4  ...                  31.4                  36.6
# 9                   26.5  ...                  29.1                  33.8
# 10                  23.3  ...                    28                  27.6
# 11                  24.5  ...                    28                  29.5
#
#           ks_adv_lit_all       ks_prof_lit_all      ks_basic_lit_all  \
# 1   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 7                   13.2                  62.2                  18.2
# 8                   11.5                  62.6                  19.3
# 9                      8                  64.8                  19.8
# 10                    10                  66.8                    17
# 11                   8.8                  63.9                  19.6
#
#         ks_below_lit_all        ks_adv_lit_hus       ks_prof_lit_hus  \
# 1   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  Not Reported in Year  Not Reported in Year
# 7                    6.4                   4.5                  50.7
# 8                    6.6                   3.7                  50.8
# 9                    7.4                   2.5                  51.1
# 10                   6.2                   3.5                  55.3
# 11                   7.7                   2.9                    51
#
#         ks_basic_lit_hus      ks_below_lit_hus
# 1   Not Reported in Year  Not Reported in Year
# 2   Not Reported in Year  Not Reported in Year
# 3   Not Reported in Year  Not Reported in Year
# 4   Not Reported in Year  Not Reported in Year
# 5   Not Reported in Year  Not Reported in Year
# 6   Not Reported in Year  Not Reported in Year
# 7                     31                  13.8
# 8                   31.7                  13.8
# 9                   31.5                  14.8
# 10                  28.5                  12.7
# 11                  30.9                  15.1
#
# [11 rows x 31 columns]

# %%
# Only keep the keystone years
outcomes_keystone = outcomes_keystone.iloc[6:,:]
outcomes_keystone
# Out:
#          year ks_number_alg_all ks_number_alg_hus ks_number_bio_all  \
# 7   2012-2013            124220             51202            122990
# 8   2013-2014            123175             53189            121505
# 9   2014-2015            123091             54760            122035
# 10  2015-2016            123525             56045            122602
# 11  2016-2017            123648             57299            122518
#
#    ks_number_bio_hus ks_number_lit_all ks_number_lit_hus ks_adv_alg_all  \
# 7              50367            123966             50978             27
# 8              52052            122784             52845           16.9
# 9              53907            122568             54180           17.7
# 10             55240            123292             55740           20.6
# 11             56357            122697             56383           22.2
#
#    ks_prof_alg_all ks_basic_alg_all  ... ks_basic_bio_hus ks_below_bio_hus  \
# 7             37.4             26.1  ...             32.5             43.4
# 8             47.1             26.4  ...             31.4             36.6
# 9             46.8             26.5  ...             29.1             33.8
# 10            47.6             23.3  ...               28             27.6
# 11            43.4             24.5  ...               28             29.5
#
#    ks_adv_lit_all ks_prof_lit_all ks_basic_lit_all ks_below_lit_all  \
# 7            13.2            62.2             18.2              6.4
# 8            11.5            62.6             19.3              6.6
# 9               8            64.8             19.8              7.4
# 10             10            66.8               17              6.2
# 11            8.8            63.9             19.6              7.7
#
#    ks_adv_lit_hus ks_prof_lit_hus ks_basic_lit_hus ks_below_lit_hus
# 7             4.5            50.7               31             13.8
# 8             3.7            50.8             31.7             13.8
# 9             2.5            51.1             31.5             14.8
# 10            3.5            55.3             28.5             12.7
# 11            2.9              51             30.9             15.1
#
# [5 rows x 31 columns]

# %%
outcomes_keystone.to_csv("./Datasets/outcomes_keystone.csv")

# %% [markdown]
# ### In people
